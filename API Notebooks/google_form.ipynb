# %%
from apiclient import discovery
from httplib2 import Http
from oauth2client import client, file, tools

# %%
with open('FORM_API_KEY.txt') as file:
    API_KEY = file.read()

# %%
{
  "formId": "13tVNOdg3QPcNVQbkz4xU48ySi4l7udQOkSJNfo01Dbk",
  "info": {
    "title": "DSA4213 MCQ",
    "documentTitle": "Test Version 1"
  },
  "revisionId": "00000002",
  "responderUri": "https://docs.google.com/forms/d/e/1FAIpQLScoEYoFbz8Ca-_wVBkzC1ElRrI_das-cYybn3RPvRQrc0g7iA/viewform"
}
# Out:
# 'AIzaSyC9S3q43cGtVSh31xaCHZy0ww_Lm1k4fHk'
