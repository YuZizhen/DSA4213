# %%
#! pip install h2ogpte

# %%
from h2ogpte import H2OGPTE
import os
import ast

# %%
! pwd
# Out:
# /Users/craig/Documents/GitHub/DSA4213/backend_api

# %% [markdown]
# # Client Creation

# %%
api_key = 'sk-xjaaELLATk2Z8apfbv1nozXFTrHmQDuQHOLsOv5V3SR6wy0U'

# %%
client = H2OGPTE(
    address='https://h2ogpte.genai.h2o.ai',
    api_key=api_key
)

chat_session_id = client.create_chat_session_on_default_collection()
# Out:
# Warning: Server version 1.4.9 doesn't match client version 1.4.0: unexpected errors may occur.
# Please install the correct version of H2OGPTE with `pip install h2ogpte==1.4.9`.
# You can enable strict version checking by passing strict_version_check=True.

# %%
print(chat_session_id)
# Out:
# 376e62ba-9982-4f3e-b6bb-d48c53ec36c9

# %% [markdown]
# ## Import the Prompts

# %%
cwd = os.getcwd()
print(cwd)
# Out:
# /Users/craig/Documents/GitHub/DSA4213/backend_api

# %%
with open('prompts/system_prompt.txt', 'r') as file:
    system_prompt = file.read()

with open('prompts/pre_prompt_query.txt', 'r') as file:
    pre_prompt_query = file.read()

with open('prompts/prompt_query.txt', 'r') as file:
    prompt_query = file.read()

# %% [markdown]
# # Client Query

# %%
qns_count = 3
context = "War and the Other"

# %%
query = f'Generate {qns_count} questions based on {context} File'
print(query)
# Out:
# Generate 3 questions based on War and the Other File

# %%
with client.connect(chat_session_id) as session:
    reply = session.query(
        message = query,
        system_prompt = system_prompt,
        pre_prompt_query = pre_prompt_query,
        prompt_query = prompt_query,
        timeout=60,
    )

print(reply.content)
# Out:
# [[["Who wrote 'Dejure belli ac pacis' on the laws of war and peace?"], ["1. Hugo Grotius", "2. Immanuel Kant", "3. Thomas Hobbes", "4. John Locke"], [1]], [["What is the main principle of Grotius' work on the laws of war and peace?"], ["1. The right to resist and the right to punish", "2. The codified law reveals 'natural law' and natural rights", "3. The entanglement between the right to fight and how to fight", "4. The hardening of concepts into customs, norms and practices"], [3]], [["What is the main principle of St. Thomas Aquinas' work on just war?"], ["1. Just cause/right intention", "2. Proper authority", "3. Last resort", "4. Probability of success", "5. Beneficial outcome", "6. Proportionality"], [1]]]

# %% [markdown]
# # Output Parsing

# %%
qns = reply.content
qns
# Out:
# '[[["Who wrote \'Dejure belli ac pacis\' on the laws of war and peace?"], ["1. Hugo Grotius", "2. Immanuel Kant", "3. Thomas Hobbes", "4. John Locke"], [1]], [["What is the main principle of Grotius\' work on the laws of war and peace?"], ["1. The right to resist and the right to punish", "2. The codified law reveals \'natural law\' and natural rights", "3. The entanglement between the right to fight and how to fight", "4. The hardening of concepts into customs, norms and practices"], [3]], [["What is the main principle of St. Thomas Aquinas\' work on just war?"], ["1. Just cause/right intention", "2. Proper authority", "3. Last resort", "4. Probability of success", "5. Beneficial outcome", "6. Proportionality"], [1]]]'

# %%
qns_list = ast.literal_eval(qns)

# %%
qns_list[0][0]
# Out:
# ["Who wrote 'Dejure belli ac pacis' on the laws of war and peace?"]
