# %%
#! pip install h2ogpte

# %%
from h2ogpte import H2OGPTE
import os
import json

# %% [markdown]
# # Client Creation

# %%
api_key = 'sk-xjaaELLATk2Z8apfbv1nozXFTrHmQDuQHOLsOv5V3SR6wy0U'

# %%
client = H2OGPTE(
    address='https://h2ogpte.genai.h2o.ai',
    api_key=api_key
)

chat_session_id = client.create_chat_session_on_default_collection()

# %%
print(chat_session_id)
# Out:
# 9f59e427-0487-4321-90c5-89bc00f4e3bf

# %% [markdown]
# ## Import the Prompts

# %%
cwd = os.getcwd()
print(cwd)
# Out:
# /Users/craig/Documents/GitHub/DSA4213/backend_api

# %%
with open('prompts/system_prompt.txt', 'r') as file:
    system_prompt = file.read()

with open('prompts/pre_prompt_query.txt', 'r') as file:
    pre_prompt_query = file.read()

with open('prompts/prompt_query.txt', 'r') as file:
    prompt_query = file.read()

# %% [markdown]
# # Client Query

# %%
qns_count = 3
context = "War and the Other"

# %%
query = f'Generate {qns_count} questions based on {context} File'
print(query)
# Out:
# Generate 3 questions based on War and the Other File

# %%
with client.connect(chat_session_id) as session:
    reply = session.query(
        message = query,
        system_prompt = system_prompt,
        pre_prompt_query = pre_prompt_query,
        prompt_query = prompt_query,
        timeout=60,
    )
    print(reply.content)
# Out:
# [[["What is the definition of 'Othering' according to S. Suzuki?"], ["1. A sociological category of analysis", "2. A cultural and political practice", "3. A positive trope", "4. A neutral concept"], [2]], [[“What is the difference between ‘othering’ the enemy and fighting because the enemy already was ‘the other’?”], ["1. There is no difference", "2. The former is based on a perceived difference, while the latter is based on an actual difference", "3. The former is a deliberate action, while the latter is a reaction", "4. The former is a cultural practice, while the latter is a sociological category"], [3]], [[“What is the main theme of the document 'War and the Other'?”], ["1. The importance of 'Othering' in war", "2. The causes of war", "3. The relationship between war and the nation or people", "4. The evolution of strategy"], [1]]]

# %% [markdown]
# # Output Parsing

# %%
qns = reply.content
qns
# Out:
# '[[["What is the definition of \'Othering\' according to S. Suzuki?"], ["1. A sociological category of analysis", "2. A cultural and political practice", "3. A positive trope", "4. A neutral concept"], [2]], [[“What is the difference between ‘othering’ the enemy and fighting because the enemy already was ‘the other’?”], ["1. There is no difference", "2. The former is based on a perceived difference, while the latter is based on an actual difference", "3. The former is a deliberate action, while the latter is a reaction", "4. The former is a cultural practice, while the latter is a sociological category"], [3]], [[“What is the main theme of the document \'War and the Other\'?”], ["1. The importance of \'Othering\' in war", "2. The causes of war", "3. The relationship between war and the nation or people", "4. The evolution of strategy"], [1]]]'

# %%
qns.replace(", ", ",")
# Out:
# '[[["What is the definition of \'Othering\' according to S. Suzuki?"],["1. A sociological category of analysis","2. A cultural and political practice","3. A positive trope","4. A neutral concept"],[2]],[[“What is the difference between ‘othering’ the enemy and fighting because the enemy already was ‘the other’?”],["1. There is no difference","2. The former is based on a perceived difference,while the latter is based on an actual difference","3. The former is a deliberate action,while the latter is a reaction","4. The former is a cultural practice,while the latter is a sociological category"],[3]],[[“What is the main theme of the document \'War and the Other\'?”],["1. The importance of \'Othering\' in war","2. The causes of war","3. The relationship between war and the nation or people","4. The evolution of strategy"],[1]]]'

# %%
json.loads(qns.replace(", ", ","))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 json.loads(qns.replace(", ", ","))
#
# File ~/opt/anaconda3/envs/llm_rag/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/opt/anaconda3/envs/llm_rag/lib/python3.9/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~/opt/anaconda3/envs/llm_rag/lib/python3.9/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 202 (char 201)

# %%
json.loads('[2]')
# Out:
# [2]
